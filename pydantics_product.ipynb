# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/Python_Projects/blob/main/pydantics_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from rich import print
from pydantic import BaseModel, field_validator

# %%
class Variant(BaseModel):
  title: str
  sku : str
  price: str
  available: bool
  taxable: bool
  grams: int

  @field_validator("sku")
  def check_sku_len(cls,value):
    required_length=10
    if len(value) != required_length:
      raise ValueError("Sku must be 10 characters long")
    return value

class Product(BaseModel):
  id : int
  title : str
  variants: list[Variant]

# %%
def get_data():
  resp = requests.get("https://www.allbirds.co.uk/products.json")
  return resp.json()["products"]

# %%
def main():
  products = get_data()
  for product in products:
    item = Product(**product)
    print(item.model_dump())

# %%
if __name__ =='__main__':
  main()
# Out:
# {
#     'id': 7159148380292,
#     'title': "Men's Wool Runner Go - Hazy Indigo (Blizzard Sole)",
#     'variants': [
#         {
#             'title': 'UK 7',
#             'sku': 'A10472M080',
#             'price': '81.00',
#             'available': True,
#             'taxable': True,
#             'grams': 783
#         },
#         {
#             'title': 'UK 7.5',
#             'sku': 'A10472M085',
#             'price': '81.00',
#             'available': True,
#             'taxable': True,
#             'grams': 801
#         },
#         {
#             'title': 'UK 8',
#             'sku': 'A10472M090',
#             'price': '81.00',
#             'available': True,
#             'taxable': True,
#             'grams': 819
#         },
#         {
#             'title': 'UK 8.5',
#             'sku': 'A10472M095',
#             'price': '81.00',
#             'available': True,
#             'taxable': True,
#             'grams': 837
#         },
#         {
# ...
